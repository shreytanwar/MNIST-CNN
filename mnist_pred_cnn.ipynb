# %% [markdown]
# <a href="https://colab.research.google.com/github/shreytanwar/MNIST-CNN/blob/main/mnist_pred_cnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import load_model
from keras.preprocessing import image
from keras.datasets import mnist

import numpy as np
import cv2
import os

import matplotlib.pyplot as plt

# %%
model = load_model('mnist.h5')

# %%
def reshape(img):
  return img.reshape(1,28,28,1)

# %%
def predict(path):
  img = image.load_img(path, color_mode="grayscale", target_size=(28,28))
  img = image.img_to_array(img)
  img = reshape(img)
  return model.predict_classes(img)

# %%
directory = 'dataset/'
fig = plt.figure(figsize=(16,16))
index = 1
for file in os.listdir(directory):
  if file.endswith(".jpg") or file.endswith(".png"):
    path = directory+file
    img = image.load_img(path)
    ax = fig.add_subplot(4,4,index)
    index=index+1
    plt.imshow(img)
    x = predict(path)
    label = "Predicted value:",x[0]
    ax.get_yaxis().set_visible(False)
    ax.set_xlabel(label)
